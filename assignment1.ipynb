# %%
#!/usr/bin/env python3
import torch
from PIL import Image
from torchvision import transforms, datasets
from torch import nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(-15, 25, 100)
y = 2*torch.sigmoid(-1*(torch.tensor(x) + 7))-1.5

# %%
plt.plot(x, y)
